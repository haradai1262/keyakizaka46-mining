# %%
# 

import pandas as pd
import re, requests
from bs4 import BeautifulSoup

import datetime
from dateutil.relativedelta import relativedelta

# %%
# setting plt

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.font_manager as fm
fm.findSystemFonts()
font = {"family":"IPAexGothic"}
mpl.rc('font', **font)

# %%
# nogizaka46

# %%
def get_month_list( start, end ):

    start_dt = datetime.datetime.strptime(start, "%Y%m")
    end_dt = datetime.datetime.strptime(end, "%Y%m")

    lst = []
    t = start_dt
    while t <= end_dt:
        lst.append(t)
        t += relativedelta(months=1)

    return [x.strftime("%Y%m") for x in lst]

def get_nogi_articles_from_single_page( page_soup ):

    titles = [ i.find('span', class_='entrytitle').text for i in page_soup.find_all('h1', class_='clearfix') ]
    authors = [ i.text for i in page_soup.find_all('span', class_='author') ]
    datetimes = [ i.text.split('｜')[0].replace(' ','').replace('\n','') for i in page_soup.find_all('div', class_='entrybottom') ]   
    texts = []
    images = []
    for i, j in enumerate( page_soup.find_all('div', class_='entrybody') ): # 画像URL抽出 ... アドホックな処理多いので注意
        image_urls = []
        for img in j.find_all('img', src=re.compile("^http(s)?://img.nogizaka46.com/blog/")):
            if img.get('src')[-4:] == '.gif':continue
            if not img.get('class') == None:
                if img.get('class')[0] == 'image-embed':
                    continue
            image_urls.append( img.get('src') )
        image_str = ''
        for img in image_urls: image_str += '%s\t'% img
        texts.append( j.text )
        images.append( image_str )

    articles = []
    for i in range( len( titles ) ):
        articles.append( [authors[i], datetimes[i], titles[i], texts[i], images[i]] )
    
    return articles

headers = {'User-Agent':'Mozilla/5.0'}

start = '201111'
end = '201901'
month_list = get_month_list( start, end )

all_articles = []
for date in month_list:
    print( date )
    target_url = 'http://blog.nogizaka46.com/?p=%d&d=%s' % (page_idx, date)
    r = requests.get(target_url, headers=headers)
    soup = BeautifulSoup(r.text, 'lxml')
    max_page_number = int( soup.find('div', class_='paginate').find_all('a')[-2].text.replace(u"\xa0",u"") ) # これでいいのか?
    for page_idx in range( 1, max_page_number+1, 1 ):
        target_url = 'http://blog.nogizaka46.com/?p=%d&d=%s' % (page_idx, date)
        r = requests.get(target_url, headers=headers)
        soup = BeautifulSoup(r.text, 'lxml')
        page_articles = get_nogi_articles_from_single_page( soup )
        all_articles.extend( page_articles )
# Out:
# 201111
# 201112
# 201201
# 201202
# 201203
# 201204
# 201205
# 201206
# 201207
# 201208
# 201209
# 201210
# 201211
# 201212
# 201301
# 201302
# 201303
# 201304
# 201305
# 201306
# 201307
# 201308
# 201309
# 201310
# 201311
# 201312
# 201401
# 201402
# 201403
# 201404
# 201405
# 201406
# 201407
# 201408
# 201409
# 201410
# 201411
# 201412
# 201501
# 201502
# 201503
# 201504
# 201505
# 201506
# 201507
# 201508
# 201509
# 201510
# 201511
# 201512
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201611
# 201612
# 201701
# 201702
# 201703
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901

# %%
# check

import pandas as pd

df = pd.DataFrame( all_articles, columns=['author', 'datetime', 'title', 'text', 'images'] )
print( df.shape )
display( df.head() )
display( df.tail() )
# Out:
# (12954, 5)
#   author         datetime                                  title  \
# 0   中田花奈  2011/11/3023:42                       コンベンション2011わずんぬ。
# 1  松村沙友理  2011/11/3014:27                         緊張なのだっ♪(o> <o)
# 2  星野みなみ  2011/11/3011:50                  やっと会えますねー(*  ´д｀*)みなみ
# 3   衛藤美彩  2011/11/3010:00  衛藤『ななみん、寒くないん(>_<)?』深川『大丈夫だよ道産子だから!!』
# 4  井上小百合  2011/11/3009:05                           ヽ(｡･ω･｡)蒼い銀河
#
#                                                 text  \
# 0  来てくださったかたニコ生見てくださったかたありがとうございます！　「部活何やってたの？」って...
# 1  こんにちりんごっ♪(ｏ・・ｏ)さゆりんごっ(o・・o)\nいきなり質問に答えます!!よろしく...
# 2  　\n　\n　\n今日はZepp東京でイベントです\n　\nもーどーしよー(・・;)\n　\...
# 3  おはよう〜(*^^*)みさみさです！　　　　\n題名は若月blogを意識してみました。。。。...
# 4  更新、遅くなってしまってごめんなさいm(__)m名古屋から帰ってきて次の日も収録、撮影、イン...
#
#                                               images
# 0  https://img.nogizaka46.com/blog/photos/uncateg...
# 1
# 2
# 3  https://img.nogizaka46.com/blog/photos/uncateg...
# 4  https://img.nogizaka46.com/blog/photos/uncateg...
#       author         datetime  \
# 12949   桜井玲香  2019/01/0215:36
# 12950   阪口珠美  2019/01/0211:00
# 12951   堀未央奈  2019/01/0121:18
# 12952    佐藤楓  2019/01/0120:36
# 12953  伊藤かりん  2019/01/0111:06
#
#                                                  title  \
# 12949                                       2019.01.02
# 12950                                     2019年坂道のぼるぞー
# 12951                                             2019
# 12952  新年、あけましておめでとうございます。明日明後日は何があっても箱根駅伝を見ましょう！ 127.
# 12953                                第421話 今年の主役はプンバァ！
#
#                                                     text  \
# 12949    明けまして おめでとうございます！  今年もどうぞよろしくお願いします！      今年...
# 12950  さかぐち 坂道 登り坂！たまにはたまみと登ってね。   あけましておめでとうございます！！！...
# 12951       新年あけましておめでとうございます☺︎   みなさんはどんなお正月をお過ごしですか...
# 12952    明けましておめでとうございます！！  佐藤楓です 新年早々ブログ失礼しますm(_ _)m...
# 12953      あけましておめでとうございます！              紅白ご覧いただきありがと...
#
#                                                   images
# 12949  https://img.nogizaka46.com/blog/reika.sakurai/...
# 12950  https://img.nogizaka46.com/blog/tamami.sakaguc...
# 12951  https://img.nogizaka46.com/blog/miona.hori/img...
# 12952  https://img.nogizaka46.com/blog/kaede.satou/im...
# 12953  https://img.nogizaka46.com/blog/karin.itou/img...

# %%
# save csv

df.to_csv( '../data/nogizaka46_blog.csv', index=0 )

# %%
# read csv

df = pd.read_csv( '../data/nogizaka46_blog.csv' )

# %%
# plot article numbers each author

fig = plt.figure(figsize=(12,4),dpi=100)
df['author'].value_counts().plot(kind='bar')
plt.show()

# %%
# keyakizaka46

# %%
def get_keyaki_articles_from_single_page( page_soup ):

    articles = []
    for i, j in enumerate( page_soup.select('article') ):
        author = j.p.text.replace(' ','').replace('\n','')
        datetime = j.find('div', class_="box-bottom").li.text.replace(' ','').replace('\n','')
        title = j.find('div', class_="box-ttl").a.text
        body = j.find('div', class_="box-article")
        text = body.text
        images = ''
        for img in  body.find_all('img'): images += '%s\t'% img.get('src')
        articles.append( [author, datetime, title, text, images] )
    
    return articles

max_page_number = 814

all_articles = []
for page_idx in range( max_page_number, -1, -1 ):
    if page_idx % 100 == 0: print(page_idx)
    target_url = 'http://www.keyakizaka46.com/s/k46o/diary/member/list?ima=0000&page=%d&cd=member' % page_idx
    r = requests.get(target_url)
    soup = BeautifulSoup(r.text, 'lxml')
    page_articles = get_keyaki_articles_from_single_page( soup )
    all_articles.extend( page_articles )
# Out:
# 800
# 700
# 600
# 500
# 400
# 300
# 200
# 100
# 0

# %%
# check

df = pd.DataFrame( all_articles, columns=['author', 'datetime', 'title', 'text', 'images'] )
print( df.shape )
display( df.head() )
display( df.tail() )
# Out:
# (16283, 5)
#   author         datetime            title  \
# 0   織田奈那  2015/11/1322:21             ドキドキ
# 1  長沢菜々香  2015/11/1322:14       長沢菜々香です^^*
# 2    守屋茜  2015/11/1322:06       祝✧初投稿。!!!!
# 3   菅井友香  2015/11/1501:06  ハラハラドキドキの1日でした!
# 4   尾関梨香  2015/11/1501:03         初!お見立て会②
#
#                                                 text  \
# 0  \n皆さんこんちには今日からブログがスタートします♡とうとう明日はお見立て会です皆さんに会え...
# 1  \nついに❗❗明日からお見立て会ですね(o^^o)✨今日の夕方頃、⊿乃木神社⊿に行って、絵馬...
# 2  \nみなさまはじめまして。守屋茜です。ご覧頂きありがとうございますヾ(*･ω･*)ﾉ いよい...
# 3  \nこんばんはっ★本日は、待ちに待ったお見立て会1日目でした!お足元の悪い中、まだまだ未熟な...
# 4  \nこんばんは☆彡尾関梨香です(^ν^)本日14日(土) Zepp DiverCity にて...
#
#                                               images
# 0  http://cdn.keyakizaka46.com/files/14/diary/k46...
# 1  http://cdn.keyakizaka46.com/files/14/diary/k46...
# 2  http://cdn.keyakizaka46.com/files/14/diary/k46...
# 3  http://cdn.keyakizaka46.com/files/14/diary/k46...
# 4  http://cdn.keyakizaka46.com/files/14/diary/k46...
#       author         datetime       title  \
# 16278  齋藤冬優花  2019/01/1107:19  1月10日(999)
# 16279   高瀬愛奈  2019/01/1107:19      BOMBさん
# 16280   東村芽依  2019/01/1107:18         みかん
# 16281   潮紗理菜  2019/01/1107:17     お星さま✩︎⡱
# 16282   齊藤京子  2019/01/1107:15     笑いすぎた一日
#
#                                                     text  \
# 16278  \n\n\n\n\n\nこんばんは☺️🤚💓\n\n\n久々にこの感覚。\nコタツで寝ました。...
# 16279  \nみなさんこんにちは(｡･ω･)ﾉﾞ 高瀬愛奈です🐰1/9発売のBOMBさん2月号にけやき...
# 16280  \n\n\n\n\nこんばんは!\n\n\n東村芽依です🍊\n\n\n本日発売の\n｢20±...
# 16281  \n\n\nこんばんは。\nそして\n遅ればせながら明けましておめでとうございます🎍‼︎\n...
# 16282  \n今日2回目のおみくじを引いたのですが大吉でした✨めちゃくちゃ嬉しい!!☺️そして今日久し...
#
#                                                   images
# 16278  http://cdn.keyakizaka46.com/images/14/339/5b8c...
# 16279  http://cdn.keyakizaka46.com/files/14/diary/k46...
# 16280  http://cdn.keyakizaka46.com/images/14/ad8/8acc...
# 16281  http://cdn.keyakizaka46.com/images/14/502/9f76...
# 16282  http://cdn.keyakizaka46.com/files/14/diary/k46...

# %%
# save csv

df.to_csv( '../data/keyaki46_blog.csv', index=0 )

# %%
# read csv

df = pd.read_csv( '../data/keyaki46_blog.csv' )

# %%
# plot article numbers each author

fig = plt.figure(figsize=(12,4),dpi=100)
df['author'].value_counts().plot(kind='bar')
plt.show()

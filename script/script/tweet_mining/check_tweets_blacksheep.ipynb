# %%
import os, sys
import json
import tweepy
import tarfile
import shutil

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

import time
from time import mktime
import datetime

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.font_manager as fm
fm.findSystemFonts()
font = {"family":"IPAexGothic"}
mpl.rc('font', **font)

# %%
# NLR

import MeCab
mecab = MeCab.Tagger (r"-Ochasen -d C:\Users\myaun\Downloads\ipadic-neologd")

import re
import unicodedata
import neologdn

from nltk.corpus import stopwords
stopWords = set(stopwords.words('english'))

from gensim import corpora, models
# Out:
# C:\Users\myaun\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# normarize

def clean_text(text):
    #replaced_text = '\n'.join(s.strip() for s in text.splitlines()[2:] if s != '')  # skip header by [2:]
    replaced_text = text.lower()
    replaced_text = re.sub(r'[【】]', ' ', replaced_text)       # 【】の除去
    replaced_text = re.sub(r'[（）()]', ' ', replaced_text)     # （）の除去
    replaced_text = re.sub(r'[［］\[\]]', ' ', replaced_text)   # ［］の除去
    replaced_text = re.sub(r'[@＠]\w+', '', replaced_text)  # メンションの除去
    #replaced_text = re.sub(r'https?:\/\/.*?[\r\n ]', '', replaced_text)  # URLの除去
    replaced_text=re.sub(r'https?://[\w/:%#\$&\?\(\)~\.=\+\-…]+', "", replaced_text)
    replaced_text = re.sub(r'　', ' ', replaced_text)  # 全角空白の除去
    for rmword in ['w', 'W', 'ｗ', 'Ｗ', '笑']:
        replaced_text = replaced_text.replace(rmword, '')
    return replaced_text

def normalize_number(text):
    replaced_text = re.sub(r'\d+', '0', text)
    return replaced_text

def normalize_text( text ):
    text = clean_text(text)
    text = unicodedata.normalize('NFC', text)
    text = neologdn.normalize(text)
    # text = normalize_number(text)    
    return text

def remove_stopwords( tokens ):
    filtered = []
    for w in tokens:
        if w not in stopWords:
            filtered.append(w)
    return filtered

# tokenize

def get_tokens( text ):
    tokens = []
    result = mecab.parseToNode( text )
    while result:
        pos = result.feature.split(',')[0]
        token.append( result.surface )
        result = result.next
    tokens = remove_stopwords( tokens )
    return tokens

def get_tokens_pos( text, target_pos ):
    nouns = []
    result = mecab.parseToNode( text )
    while result:
        pos = result.feature.split(',')[0]
        if pos in target_pos:
            nouns.append( result.surface )
        result = result.next
    tokens = remove_stopwords( nouns )
    return tokens

def get_nouns( text ):
    nouns = []
    result = mecab.parseToNode( text )
    while result:
        pos = result.feature.split(',')[0]
        if pos == '名詞': nouns.append( result.surface )
        result = result.next
    tokens = remove_stopwords( nouns )
    return tokens

def get_entity( text ):
    entity = []
    result = mecab.parseToNode( text )
    while result:
        line = result.feature.split(',')
        pos, tag = line[0], line[1]
        if tag == '固有名詞': entity.append( result.surface )
        result = result.next
    tokens = remove_stopwords( entity )
    return tokens

# %%
def load_tweets( query ):
    savepath =  "./data/tweet"
    query_dir = "%s/%s" % (savepath, query)
    if not os.path.exists( query_dir ):
        os.mkdir(query_dir)

    rows = []
    files = os.listdir(query_dir)
    for idx, file in enumerate(files):
        if os.path.isfile( "%s/%s" % (query_dir, file) ): # file
            taffile_path = "%s/%s" % (query_dir, file)
            tf = tarfile.open( taffile_path , 'r')
            for fname_in_tar in tf.getnames():
                f = tf.extractfile( fname_in_tar )
                tweet = json.loads( f.read().decode() )
                struct = time.strptime(tweet['created_at'],'%a %b %d %H:%M:%S +0000 %Y')
                dt = datetime.datetime.fromtimestamp(mktime(struct))
                dt_diff = dt + datetime.timedelta(hours=9)
                rows.append( [dt_diff, tweet['id'], tweet['text']] )  
        else: # dir
            target_dir = "%s/%s" % (query_dir, file)
            files = os.listdir(target_dir)
            for idx, file in enumerate(files):
                f = open('%s/%s' % (target_dir, file), 'r')
                tweet = json.load(f)
                f.close()

                struct = time.strptime(tweet['created_at'],'%a %b %d %H:%M:%S +0000 %Y')
                dt = datetime.datetime.fromtimestamp(mktime(struct))
                dt_diff = dt + datetime.timedelta(hours=9)
                rows.append( [dt_diff, tweet['id'], tweet['text']] )
    return rows

# %%
query = "#欅坂46"
rows = load_tweets( query )
df_sol = pd.DataFrame( rows, columns=['created_at', 'id', 'text'] )
onair_time = ['2019-01-21 22:20', '2019-01-21 23:20']
df_onair = df_sol.query('created_at > "%s" and created_at < "%s"' % (onair_time[0], onair_time[1]))

df_onair['created_at'].groupby([df_onair["created_at"].dt.hour, df_onair["created_at"].dt.minute]).count().plot(
    x='time', kind="bar", color="orange", figsize=(20, 8))
plt.xlabel("time", fontdict={'size': 12})
plt.ylabel("tweet count", fontdict={'size': 12})
plt.show()

# %%
query = "#SOL"
rows = load_tweets( query )
df_sol = pd.DataFrame( rows, columns=['created_at', 'id', 'text'] )
onair_time = ['2019-01-21 22:20', '2019-01-21 23:20']
df_onair = df_sol.query('created_at > "%s" and created_at < "%s"' % (onair_time[0], onair_time[1]))

df_onair['created_at'].groupby([df_onair["created_at"].dt.hour, df_onair["created_at"].dt.minute]).count().plot(
    x='time', kind="bar", color="orange", figsize=(20, 8))
plt.xlabel("time", fontdict={'size': 12})
plt.ylabel("tweet count", fontdict={'size': 12})
plt.show()

# %%
query = "#黒い羊"
rows = load_tweets( query )
df = pd.DataFrame( rows, columns=['created_at', 'id', 'text'] )
onair_time = ['2019-01-21 22:20', '2019-01-21 23:20']
df_onair = df.query('created_at > "%s" and created_at < "%s"' % (onair_time[0], onair_time[1]))

df_onair['created_at'].groupby([df_onair["created_at"].dt.hour, df_onair["created_at"].dt.minute]).count().plot(
    x='time', kind="bar", color="orange", figsize=(20, 8))
plt.xlabel("time", fontdict={'size': 12})
plt.ylabel("tweet count", fontdict={'size': 12})
plt.show()

# %%
query = "#黒い羊"
rows = load_tweets( query )
df_sol = pd.DataFrame( rows, columns=['created_at', 'id', 'text'] )
onair_time = ['2019-01-21 22:20', '2019-01-21 23:20']
df_onair = df_sol.query('created_at > "%s" and created_at < "%s"' % (onair_time[0], onair_time[1]))
grouped = df_onair.groupby([df["created_at"].dt.hour, df["created_at"].dt.minute])
for idx, key in enumerate( grouped.groups.keys()):
    texts = grouped.get_group(key)['text'].values.tolist()
    BoE = [ get_entity( normalize_text( text ) ) for text in texts ]
    dictionary = corpora.Dictionary( BoE )
    top10 = [ dictionary[i] for i, j in sorted( dictionary.dfs.items(), key=lambda x:x[1], reverse=True)[:10] ]
    print( '%2d時%2d分  tweet_num:%d　-> keywords:' % (key[0], key[1], len(texts)), top10 )
# Out:
# 22時20分  tweet_num:23　-> keywords: ['sol', '欅坂46', '平手友梨奈', 'スクールオブロック', 'てち', 'もうすぐだ', '平手', '友梨奈', 'イヤホン', '8t']
# 22時21分  tweet_num:27　-> keywords: ['sol', '平手友梨奈', '欅坂46', 'てち', 'パルコ', 'girls', '甘噛み', 'あけおめ', 'oa', '欅坂']
# 22時22分  tweet_num:26　-> keywords: ['sol', '欅坂46', '平手友梨奈', 'てち', 'school of lock!', '今日だけは', 'ok', 'カミカミ', 'ジングル', '好きな人']
# 22時23分  tweet_num:27　-> keywords: ['sol', '平手友梨奈', '欅坂46', 'てち', 'パルコ', 'school of lock!', 'schooloflock', 'ゆりな', 'スクールオブロック', '平手']
# 22時24分  tweet_num:13　-> keywords: ['sol', '欅坂46', '平手友梨奈', 'てち', '平手', 'きたあ', 'ガールズ', '共喰い', 'パルコ', '好きな人']
# 22時25分  tweet_num:12　-> keywords: ['sol', '平手友梨奈', '欅坂46', 'てち', 'schooloflock', 'マジで', '立ち位置', '3列目', 'もん', '???']
# 22時26分  tweet_num:11　-> keywords: ['sol', '平手友梨奈', '欅坂46', 'てち', 'キャロ', 'ふー', '好きな人', '3週目', 'schooloflock', 'まーす']
# 22時27分  tweet_num:17　-> keywords: ['sol', '平手友梨奈', '欅坂46', 'てち', 'school of lock!', 'バンジー', 'けやかけ', '欅坂', '胃が痛い', 'アロエヨーグルト']
# 22時28分  tweet_num:9　-> keywords: ['sol', '平手友梨奈', '欅坂46', 'てち', 'まーす', 'school of lock!', 'わ!', 'マカオ', '友梨奈', '好きな人']
# 22時29分  tweet_num:25　-> keywords: ['sol', '欅坂46', '平手友梨奈', 'school of lock!', '8t', 'てち', 'バンジー', '好きな人', 'テム・レイ', 'キター']
# 22時30分  tweet_num:36　-> keywords: ['sol', '欅坂46', '平手友梨奈', 'てち', '8t', '好きな人', 'じゃなくて', 'パルコ', 'bgm', 'お餅']
# 22時31分  tweet_num:88　-> keywords: ['sol', '欅坂46', '平手友梨奈', 'キター', 'イントロ', 'てち', '好きな人', 'ω', '8枚', 'radiko']
# 22時32分  tweet_num:110　-> keywords: ['sol', '欅坂46', 'てち', '平手友梨奈', 'イントロ', '平手', '8t', '神曲', '欅坂', 'tokyofm']
# 22時33分  tweet_num:144　-> keywords: ['sol', '欅坂46', 'てち', '平手友梨奈', 'イントロ', '欅坂', '神曲', '8t', '???', 'schooloflock']
# 22時34分  tweet_num:197　-> keywords: ['sol', '欅坂46', 'てち', 'イントロ', '神曲', '8t', '平手友梨奈', '平手', '欅坂', 'キター']
# 22時35分  tweet_num:234　-> keywords: ['sol', '欅坂46', 'てち', 'イントロ', '平手友梨奈', '神曲', '欅坂', '8t', '平手', 'わ!']
# 22時36分  tweet_num:278　-> keywords: ['sol', '欅坂46', 'てち', '平手友梨奈', '神曲', '欅坂', 'ω', '8t', '平手', 'mv']
# 22時37分  tweet_num:365　-> keywords: ['sol', '欅坂46', 'てち', '神曲', '平手友梨奈', '8t', '欅坂', 'イントロ', 'mv', 'メッセージ性']
# 22時38分  tweet_num:402　-> keywords: ['sol', '欅坂46', 'てち', '神曲', '平手友梨奈', 'mv', '8t', '欅坂', 'イントロ', '表題曲']
# 22時39分  tweet_num:442　-> keywords: ['sol', '欅坂46', 'てち', '神曲', '平手友梨奈', 'mv', '8t', '欅坂', 'メッセージ性', '表題曲']
# 22時40分  tweet_num:420　-> keywords: ['sol', '欅坂46', 'てち', '神曲', 'mv', '平手友梨奈', '8t', '欅坂', 'メッセージ性', 'イントロ']
# 22時41分  tweet_num:375　-> keywords: ['欅坂46', 'sol', 'てち', 'mv', '神曲', '欅坂', '平手友梨奈', 'イントロ', '8t', 'メッセージ性']
# 22時42分  tweet_num:339　-> keywords: ['欅坂46', 'sol', 'てち', '神曲', 'mv', '平手友梨奈', '欅坂', '8t', 'イントロ', '涙']
# 22時43分  tweet_num:277　-> keywords: ['欅坂46', 'sol', 'mv', 'てち', '神曲', '8t', '平手友梨奈', 'イントロ', '欅坂', 'メッセージ性']
# 22時44分  tweet_num:230　-> keywords: ['欅坂46', 'sol', 'てち', 'mv', '平手友梨奈', '神曲', '欅坂', 'アンビバレント', '平手', '表題曲']
# 22時45分  tweet_num:188　-> keywords: ['欅坂46', 'sol', 'てち', '8t', '平手友梨奈', '欅坂', 'mv', '神曲', '8枚', '表題曲']
# 22時46分  tweet_num:184　-> keywords: ['欅坂46', 'sol', 'てち', 'mv', '神曲', '8t', '平手友梨奈', 'イントロ', '欅坂', '表題曲']
# 22時47分  tweet_num:167　-> keywords: ['欅坂46', 'sol', 'てち', '神曲', 'mv', '平手友梨奈', '8t', '表題曲', 'イントロ', '欅坂']
# 22時48分  tweet_num:136　-> keywords: ['欅坂46', 'sol', 'てち', '平手友梨奈', '欅坂', '神曲', '8t', 'mv', 'イントロ', '表題曲']
# 22時49分  tweet_num:153　-> keywords: ['欅坂46', 'てち', 'sol', 'mv', '神曲', '平手友梨奈', 'イントロ', '8t', '平手', 'カップリング曲']
# 22時50分  tweet_num:137　-> keywords: ['欅坂46', 'sol', 'てち', '神曲', 'mv', '平手友梨奈', '8t', '欅坂', '平手', 'イントロ']
# 22時51分  tweet_num:128　-> keywords: ['欅坂46', 'sol', 'てち', 'mv', '欅坂', '8t', '神曲', '平手友梨奈', '468t', '平手']
# 22時52分  tweet_num:111　-> keywords: ['欅坂46', 'sol', '平手友梨奈', '神曲', 'てち', '8t', 'メッセージ性', 'mv', '1番', '表題曲']
# 22時53分  tweet_num:112　-> keywords: ['欅坂46', 'sol', 'てち', '平手友梨奈', 'mv', '8t', '欅坂', '表題曲', '神曲', '個人的']
# 22時54分  tweet_num:108　-> keywords: ['欅坂46', 'sol', 'てち', '欅坂', '8t', 'mv', '神曲', 'メッセージ性', '個人的', '平手']
# 22時55分  tweet_num:104　-> keywords: ['欅坂46', 'てち', 'sol', 'mv', '平手友梨奈', '8t', 'イントロ', '神曲', '個人的', '表題曲']
# 22時56分  tweet_num:103　-> keywords: ['欅坂46', 'mv', 'てち', '平手友梨奈', 'sol', '神曲', '欅坂', '8t', 'フォーメーション', 'イントロ']
# 22時57分  tweet_num:110　-> keywords: ['欅坂46', 'てち', 'sol', '平手友梨奈', '神曲', 'mv', '8t', '欅坂', '表題曲', 'メッセージ性']
# 22時58分  tweet_num:83　-> keywords: ['欅坂46', 'mv', 'てち', '欅坂', 'sol', '平手友梨奈', '神曲', '8t', '個人的', 'なのか']
# 22時59分  tweet_num:101　-> keywords: ['欅坂46', 'sol', '神曲', 'てち', 'mv', '8t', '欅坂', '平手友梨奈', '表題曲', 'メッセージ性']
# 23時 0分  tweet_num:93　-> keywords: ['欅坂46', 'sol', 'てち', '平手友梨奈', '8t', '欅坂', 'mv', 'スーパームーン', 'アジアカップ', '錦織圭']
# 23時 1分  tweet_num:78　-> keywords: ['欅坂46', 'てち', '欅坂', 'sol', '8t', 'mv', '平手友梨奈', '神曲', 'フォーメーション', '表題曲']
# 23時 2分  tweet_num:69　-> keywords: ['欅坂46', 'てち', '8t', '平手', 'sol', '涙', '平手友梨奈', '欅坂', '神曲', '世界観']
# 23時 3分  tweet_num:65　-> keywords: ['欅坂46', 'sol', '8t', '欅坂', 'てち', '神曲', '1番', '平手友梨奈', 'mv', '468t']
# 23時 4分  tweet_num:64　-> keywords: ['欅坂46', 'てち', 'sol', '神曲', 'mv', '8t', 'イントロ', '平手友梨奈', '1番', '織田']
# 23時 5分  tweet_num:78　-> keywords: ['欅坂46', '欅坂', 'sol', 'てち', 'mv', 'イントロ', '8t', '神曲', '涙', '表題曲']
# 23時 6分  tweet_num:57　-> keywords: ['欅坂46', 'てち', 'sol', '8t', '平手友梨奈', 'mv', '欅坂', 'イントロ', '神曲', '1番']
# 23時 7分  tweet_num:60　-> keywords: ['欅坂46', 'てち', 'mv', '8t', '欅坂', 'h', 'コール', 'サイリウム', '表題曲', 'sol']
# 23時 8分  tweet_num:57　-> keywords: ['欅坂46', '欅坂', '神曲', 'てち', 'mv', '語彙力', 'イントロ', '8t', '平手', 'sol']
# 23時 9分  tweet_num:63　-> keywords: ['欅坂46', 'てち', '平手友梨奈', '神曲', '8t', 'mv', '欅坂', 'sol', '平手', '468t']
# 23時10分  tweet_num:48　-> keywords: ['欅坂46', 'mv', '欅坂', 'sol', '平手友梨奈', '神曲', 'てち', '8t', '2番', 'メッセージ性']
# 23時11分  tweet_num:44　-> keywords: ['欅坂46', 'てち', '神曲', '8t', '欅坂', 'sol', '平手友梨奈', '1番', 'mv', '3位']
# 23時12分  tweet_num:50　-> keywords: ['欅坂46', 'てち', 'mv', '神曲', '8t', '欅坂', 'sol', 'イントロ', '1度目', '類似点']
# 23時13分  tweet_num:52　-> keywords: ['欅坂46', 'てち', '8t', '平手友梨奈', '神曲', '欅坂', '表題曲', 'じゃなくて', '1番', '2番']
# 23時14分  tweet_num:51　-> keywords: ['欅坂46', 'てち', '欅坂', '平手', '神曲', 'sol', 'イントロ', '8枚', '個人的', '8t']
# 23時15分  tweet_num:42　-> keywords: ['欅坂46', 'sol', '欅坂', 'mv', 'イントロ', '平手友梨奈', '平手', 'てち', '8枚', '森']
# 23時16分  tweet_num:59　-> keywords: ['欅坂46', 'てち', 'mv', '欅坂', '平手友梨奈', 'sol', 'ナスカ', '個人的', '何回', '平手']
# 23時17分  tweet_num:46　-> keywords: ['欅坂46', '8t', 'てち', 'mv', 'sol', '欅坂', 'いいね', '神曲', 'イントロ', '平手']
# 23時18分  tweet_num:34　-> keywords: ['欅坂46', 'てち', 'sol', '神曲', '平手友梨奈', '欅坂', '厄介者', '鈴本美愉', '澤部佑', 'ガチ']
# 23時19分  tweet_num:51　-> keywords: ['欅坂46', 'mv', 'sol', 'てち', 'イントロ', '欅坂', '468t', 'まーす', 'schooloflock', '平手友梨奈']

# %%
onair_time = ['2019-01-21 22:30', '2019-01-21 23:59']
df_target = df.query('created_at > "%s" and created_at < "%s"' % (onair_time[0], onair_time[1]))
texts = df_target['text'].values.tolist()
# BoE = [ get_entity( normalize_text( text ) ) for text in texts ]
BoW = [ get_tokens_pos( normalize_text( text ), ['名詞','形容詞'] ) for text in texts ]
# BoW = [ get_tokens_pos( normalize_text( text ), ['形容詞'] ) for text in texts ]

text = ""
for entities in BoW:
    for e in entities:
        text += '%s '%e

#stopwords = ["欅坂46", "SOL"]
#for w in stopwords:
#    text = text.replace(w,'')

# %%
get_wordcrowd(text)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
from wordcloud import WordCloud
fpath = "C:\Windows\Fonts\meiryob.ttc"

def get_wordcrowd( text ):
    wordcloud = WordCloud(background_color="black",
                          collocations=False,
                          font_path=fpath,
                          width=800,
                          height=600,
                          # stopwords=set(lower_dfs),
                         ).generate( text )

    plt.figure(figsize=(12,9), dpi=200)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
